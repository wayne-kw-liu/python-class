# %%
# Import libraries
import requests 
from bs4 import BeautifulSoup

def get_price_com(query):
    # Open web page
    URL = "https://www.price.com.hk/search.php?g=A&q=" + query
    r = requests.get(URL)
    soup = BeautifulSoup(r.text)
    
    # Get total number of page
    page_str = ""
    for i in soup.find('div',{'class':'pagination-bottom-center'}).findAll('a')[-1]['onclick']:
        if i.isdigit(): page_str = page_str + i
    total_page = int(page_str)
    
    # Set up product library
    product_lib = {}

    # Scrape from page 1 to last page 
    for page in range(1, total_page + 1):
        if page > 1:
            URL = "https://www.price.com.hk/search.php?g=A&q="+query+'&page=' + str(page)
            r = requests.get(URL)
            soup = BeautifulSoup(r.text)
        product_list = soup.find('ul',{'tag':'product-list'})
        li = product_list.findAll('li')
        for product in li:
            # Skip invalid line
            if product.find('input') == None: continue
            if not 'data-add-compare-name' in product.find('input').attrs: continue
            # Scrape Product Name
            product_name = product.find('input')['data-add-compare-name']
            # Set up library to store product features
            feature_lib = {}
            # Scrape Price
            price_lib = {}
            price_range = []
            spans = product.findAll('span')
            for span in spans:
                if 'data-price' in span.attrs:
                    price_range.append(float(span['data-price']))
                if 'class' in span.attrs and span['class'] == ['product-prop']:
                    if span.find('img') != None: 
                        product_prop = span.find('img')['title']
                    else: product_prop = "其他"
                    price_lib[product_prop] = price_range
                    price_range = []
                feature_lib['price'] = price_lib
            # Scrape Rating
            rating = product.find('span',{'class':'product-rating'})
            if rating != None:
                feature_lib['rating'] = rating.find('img')['alt']
            # Scrape Spec
            trs = product.findAll('tr')
            spec_lib = {}
            for tr in trs:
                spec_lib[tr.find('td',{'class':'attr-label'}).text] = tr.find('span').text
            if len(spec_lib) > 0: feature_lib['spec'] = spec_lib
            # Scrape Caption
            caption = product.find('span',{'class':'product-caption'})
            if caption != None:
                feature_lib['caption'] = caption.text
            # Save feature to product library with product name as the key
            product_lib[product_name] = feature_lib
    
    # Return product library
    return product_lib

# %%
dyson_list = get_price_com('dyson')

# %%
dyson_list['Dyson Supersonic 風筒 HD15']['spec']
# Out:
# {'功率:': '1600W',
#  '電源線長度:': '2.8m',
#  '風速調節:': '3',
#  '熱風模式:': '4',
#  '冷風功能:': '有',
#  '負離子護髮功能:': '有'}

# %%
dyson_list['Dyson V8 Slim Fluffy 無線吸塵機']['price']
# Out:
# {'行貨': [2480.0, 3180.0], '水貨': [2290.0, 2780.0]}

# %%
dyson_list['Dyson Digital Slim Origin 輕量無線吸塵機']['rating']
# Out:
# '10'

# %%
dyson_list['Dyson Purifier Hot+Cool Gen1 三合一暖風空氣清新機 HP10']['caption']
# Out:
# '(自動感應、有效捕捉灰塵、致敏原、細菌及H1N1 病毒7，帶來更潔淨的空氣。 \xa0全室淨化，為你吹送暖風或涼風。 \xa0全機密封符合HEPA H13標準。 \xa0去除99.95％小至PM 0.1 的微粒。)'

# %%
dyson_list['Dyson V15 Detect Total Clean 智能無線吸塵機']
# Out:
# {'price': {'行貨': [4780.0, 5780.0], '水貨': [3980.0]},
#  'rating': '10',
#  'spec': {'類型:': '直立式',
#   '無線:': '是',
#   '吸力:': '230AW',
#   '集塵方式:': '塵盒',
#   '集塵量:': '0.54公升',
#   '除塵蟎:': '有',
#   '尺寸:': '266 x 1086 x 250mm',
#   '重量:': '2.61kg'},
#  'caption': '(精準角度的雷射光使硬地板上隱藏的微塵清晰可見。内置壓電式聲學感應器( LCD)可持續偵測微粒大小和數量，並在需要時自動增加吸力。)'}

# %%
print(dyson_list)
# Out:
# {'Dyson Supersonic 風筒 HD15': {'price': {'行貨': [2650.0, 3678.0]}, 'rating': '9.8', 'spec': {'功率:': '1600W', '電源線長度:': '2.8m', '風速調節:': '3', '熱風模式:': '4', '冷風功能:': '有', '負離子護髮功能:': '有'}, 'caption': '(顏色: 銀銅色 / 桃紅色 / 黑鋼色)'}, 'Dyson Supersonic 風筒 普魯士藍冬日限定版 HD08': {'price': {'行貨': [2700.0, 3280.0], '水貨': [3880.0]}, 'rating': '10', 'spec': {'功率:': '1600W', '風速調節:': '3', '冷風功能:': '有', '負離子護髮功能:': '有'}}, 'Dyson Gen5Detect Absolute 無線吸塵機': {'price': {'行貨': [4760.0, 6520.0]}, 'rating': '9.6', 'spec': {'類型:': '直立式,手提式', '無線:': '是', '吸力:': '262AW', '集塵方式:': '塵盒', '集塵量:': '0.77公升', '尺寸:': '1276 x 276 x 250mm', '重量:': '3.2kg'}, 'caption': '(G5 Detect Absolute)'}, 'Dyson V8 Slim Fluffy 無線吸塵機': {'price': {'行貨': [2480.0, 3180.0], '水貨': [2290.0, 2780.0]}, 'rating': '9.6', 'spec': {'類型:': '直立式,手提式', '無線:': '是', '吸力:': '115AW', '集塵方式:': '塵盒', '集塵量:': '0.54公升', '尺寸:': '210 x 1123 x 250mm', '重量:': '2.15kg'}, 'caption': '(輕量無線，吸力同樣強勁。 全新輕量軟絨毛滾筒吸頭 、 更小、更輕。)'}, 'Dyson Supersonic 風筒 HD08': {'price': {'行貨': [2430.0, 3300.0], '水貨': [2320.0, 2980.0]}, 'rating': '9.7', 'spec': {'功率:': '1600W', '電壓:': '220-240V', '電源線長度:': '2.8m', '風速調節:': '3', '冷風功能:': '有', '負離子護髮功能:': '有'}}, 'Dyson V15 Detect Total Clean 智能無線吸塵機': {'price': {'行貨': [4780.0, 5780.0], '水貨': [3980.0]}, 'rating': '10', 'spec': {'類型:': '直立式', '無線:': '是', '吸力:': '230AW', '集塵方式:': '塵盒', '集塵量:': '0.54公升', '除塵蟎:': '有', '尺寸:': '266 x 1086 x 250mm', '重量:': '2.61kg'}, 'caption': '(精準角度的雷射光使硬地板上隱藏的微塵清晰可見。内置壓電式聲學感應器( LCD)可持續偵測微粒大小和數量，並在需要時自動增加吸力。)'}, 'Dyson V12s Origin Submarine 乾濕全能洗地吸塵機': {'price': {'行貨': [4390.0, 4880.0]}, 'rating': '未有任何評分', 'spec': {'類型:': '直立式,手提式', '無線:': '是', '吸力:': '120AW', '集塵方式:': '塵盒', '集塵量:': '0.35公升', '尺寸:': '1234 x 252 x 250mm', '重量:': '2.2kg'}, 'caption': '(深層清潔力，現可清洗硬地板。乾濕全能洗地吸塵機 | 捕捉並鎖住微粒，包括致敏原 | 使用時間長達60分鐘 \r\n 快速吸除毛髮，避免纏結)'}, 'Dyson 風扇暖風機 AM09': {'price': {'行貨': [2500.0, 3200.0], '水貨': [2680.0]}, 'rating': '9.0', 'spec': {'類型:': '無葉扇', '尺寸:': '595mm'}}, 'Dyson V12s Detect Slim Submarine 乾濕全能洗地吸塵器': {'price': {'行貨': [4860.0, 5480.0]}, 'rating': '10', 'spec': {'類型:': '直立式,手提式', '無線:': '是', '吸力:': '140AW', '集塵方式:': '塵盒', '集塵量:': '0.35公升', '尺寸:': '1234 x 252 x 250mm', '重量:': '2.2kg'}}, 'Dyson Supersonic 風筒 長春花藍配玫瑰金限定版 附精美禮盒 HD15': {'price': {'行貨': [2700.0, 3550.0]}, 'rating': '9.8', 'spec': {'功率:': '1600W', '電源線長度:': '2.8m', '風速調節:': '3', '熱風模式:': '4', '冷風功能:': '有', '負離子護髮功能:': '有'}}, 'Dyson Supersonic 風筒 普魯士藍配精美禮盒 HD15': {'price': {'行貨': [2700.0, 3480.0]}, 'rating': '10', 'spec': {'功率:': '1600W', '電源線長度:': '2.8m', '風速調節:': '3', '熱風模式:': '4', '冷風功能:': '有', '負離子護髮功能:': '有'}, 'caption': '(四種造型配件 / 包括全新二合一抗毛躁順髮風嘴 /\xa0智能熱控 /\xa0使用 Dyson V9數碼摩打)'}, 'Dyson Purifier Hot+Cool Gen1 三合一暖風空氣清新機 HP10': {'price': {'行貨': [3700.0, 4130.0]}, 'rating': '未有任何評分', 'spec': {'HEPA過濾網:': '有', '睡眠模式:': '有', '尺寸:': '765 x 250 x 250mm', '重量:': '5.2kg'}, 'caption': '(自動感應、有效捕捉灰塵、致敏原、細菌及H1N1 病毒7，帶來更潔淨的空氣。 \xa0全室淨化，為你吹送暖風或涼風。 \xa0全機密封符合HEPA H13標準。 \xa0去除99.95％小至PM 0.1 的微粒。)'}, 'Dyson Digital Slim Origin 輕量無線吸塵機': {'price': {'行貨': [2750.0, 3180.0]}, 'rating': '10', 'spec': {'類型:': '直立式,手提式', '無線:': '是', '吸力:': '100AW', '集塵方式:': '塵盒', '集塵量:': '0.35公升', '尺寸:': '1100 x 250 x 233mm', '重量:': '1.8kg'}}, 'Dyson Corrale 直捲髮造型器 HS07': {'price': {'行貨': [3080.0]}, 'rating': '10', 'spec': {'類型:': '直髮夾', '有線/無線:': '無線', '功率:': '200W', '溫度選擇:': '165°C, 185°C, 210°C', '自動斷電:': '閒置10分鐘'}, 'caption': '(戴森 Dyson Corrale HS07 直髮造型器極緻造型體驗 減少50%熱傷害，無線隨心掌控。能塑造各種不同造型 – 從捲曲和波浪造型，到柔滑亮麗直髮。顏色-桃紅色/普魯士藍/銀銅色)'}, 'Dyson Supersonic 風筒 炫彩粉霧拼色配精美禮盒 HD15': {'price': {'行貨': [3160.0, 3780.0]}, 'rating': '未有任何評分', 'spec': {'功率:': '1600W', '電源線長度:': '2.8m', '風速調節:': '3', '熱風模式:': '4', '冷風功能:': '有', '負離子護髮功能:': '有'}, 'caption': '(四種造型配件，包括全新二合一抗毛躁順髮風嘴。智能熱控，使用 Dyson V9數碼摩打。專為頭髮及頭皮修護設計。)'}, 'Dyson V12 Detect Slim Fluffy Plus 智能輕量無線吸塵機': {'price': {'行貨': [3870.0]}, 'rating': '9.0', 'spec': {'類型:': '直立式,手提式', '無線:': '是', '吸力:': '140AW', '集塵方式:': '塵盒', '集塵量:': '0.35公升', '尺寸:': '1234 x 250 x 252mm', '重量:': '2.2kg'}, 'caption': '(Dyson強勁輕量智能無線吸 ...
